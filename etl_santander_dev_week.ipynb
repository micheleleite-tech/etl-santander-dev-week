# %%
import pandas as pd

df = pd.read_csv("clientes.csv")
df
# Out:
#       nome  conta    cartao
# 0      Ana  12345  ****1234
# 1   Carlos  67890  ****5678
# 2  Mariana  54321  ****9876

# %% [markdown]
# ## Extract
# Leitura dos dados a partir de um arquivo CSV.

# %% [markdown]
# ## Transform
# Geração de mensagens personalizadas para cada cliente.

# %%
df.to_csv("clientes_com_mensagem.csv", index=False)

# %% [markdown]
# ## Load
# Salvamento dos dados transformados em um novo arquivo CSV.
